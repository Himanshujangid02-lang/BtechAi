# %%
a=50
type(a)
# Out:
# int

# %%
a=50
type(a)
# Out:
# int

# %%
int main()
{
    int fact=1;
    int n=5;
    for(i=1;i<=n;i++)
    fact*=i;
    printf("factorial=%d",fact);
    return0;
}
# Out:
#   File "/tmp/ipykernel_1043/2657312271.py", line 1
#     int main()
#         ^
# SyntaxError: invalid syntax

# %%
fact=1
n=5
i=1
while i<=n:
   fact *= i
   i+=1
print(fact)
# Out:
# 120

# %%
for i in range(1,12,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %%
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# for i in range(5):
#     print(i)

# %%
fact=1
n=5
for i in range(1,n+1):
    fact *=i
print(fact)
# Out:
# 120
